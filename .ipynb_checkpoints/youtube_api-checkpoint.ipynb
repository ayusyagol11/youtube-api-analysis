# %% [markdown]
# # Analysing my Youtube Channels performance (Ayusy)

# %% [markdown]
# ## 1. Aim and Objectives

# %% [markdown]
# The aim of this project is to conduct an exploratory data analysis of video performance data from the Ayusy YouTube channel to identify patterns and actionable insights that can improve the channel's reach and engagement.
#
# ### Objectives
# - **Utilize YouTube API**: Learn to access and extract video data from the YouTube API, gaining familiarity with the structure and content of YouTube analytics.
# - **Analyze Video Performance**: Examine various factors that influence video performance to validate or refute common beliefs about what makes a video successful on YouTube. Specific questions to be addressed include:
#     - **Impact of Engagement**: Does the number of likes and comments significantly impact a video's view count and overall reach?
#     - **Video Duration**: How does video length affect views and engagement (likes and comments)? Is there an optimal duration for videos?
#     - **Title Length**: Does the length of a video's title influence view count, and if so, what is the optimal range?
#     - **Tags**: What role do tags play in video performance? Are there optimal tag counts, and what are the common tags among high-performing videos?
#     - **Audience Interaction**: What types of questions or comments do viewers leave, and how can these insights be used to enhance future content?
#
# By analyzing these aspects, the project aims to provide data-driven recommendations to optimize content strategy and engagement for the Ayusy YouTube channel.

# %% [markdown]
# ## 2. Data Collection

# %%
import pandas as pd
import numpy as np
from dateutil import parser
import isodate

# Data visualization libraries
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import plotly.graph_objects as go
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

# Google API: To setup the Youtube API which will be used to collect data from the channel.
from googleapiclient.discovery import build

# %%
# NLP libraries: for basic NLP tasks to analyze and process comment text data.
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/aayushyagol/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/aayushyagol/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### 2.1 Retrieving data from Youtube API

# %%
#storing the API key and Channel ID in variables
api_key = 'AIzaSyAo1TbIcAzQB9CtLTixYsMAie5X85Ov5-o'

channel_ids = ['UCKp9UfULbI3n6_VdUxV2_jg']

api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %% [markdown]
# ### 2.2 Getting Channel Statistics

# %%
def get_channel_stats(youtube, channel_ids):
    """
    Get channel statistics: title, subscriber count, view count, video count, upload playlist
    """
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    #loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }           
        all_data.append(data)
    
    return(pd.DataFrame(all_data))

# %% [markdown]
# ### 2.3 Get Video IDs from a Playlist
# - Retrieves a list of video IDs for each channel’s playlist.
# - Loops through each page of playlist items, retrieving up to 50 video IDs per page until there are no more pages.

# %%
playlist_id = "UUKp9UfULbI3n6_VdUxV2_jg"

def get_video_ids (youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request. execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])

    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part="snippet,contentDetails",
                    playlistId=playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request. execute()
            
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])
        
        next_page_token = response.get('nextPageToken')
                         
    return video_ids

# %% [markdown]
# ### 2.4 Getting Video Details
# - Gathers detailed statistics (views, likes, comments, duration) for each video.
# - Collects data from the videos endpoint in batches of 50 for efficiency, as there is a limit on the number of IDs that can be requested simultaneously.
# - Handles potential missing fields by setting missing values to None.

# %%
def get_video_details(youtube, video_ids):
    """
    Get video statistics of all videos with given IDs
    Params:
    
    youtube: the build object from googleapiclient.discovery
    video_ids: list of video IDs
    
    Returns:
    Dataframe with statistics of videos, i.e.:
        'channelTitle', 'title', 'description', 'tags', 'publishedAt'
        'viewCount', 'likeCount', 'favoriteCount', 'commentCount'
        'duration', 'definition', 'caption'
    """
        
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

# %% [markdown]
# ### 2.5 Getting Comments on Videos
# - Attempts to gather comments for each video, handling any errors if comments are disabled.
# - Each comment set is added to a DataFrame for easy access.

# %%
def get_comments_in_videos(youtube, video_ids):
    """
    Get top level comments as text from all videos with given IDs (only the first 10 comments due to quote limit of Youtube API)
    Params:
    
    youtube: the build object from googleapiclient.discovery
    video_ids: list of video IDs
    
    Returns:
    Dataframe with video IDs and associated top level comment in text.
    
    """
    all_comments = []
    
    for video_id in video_ids:
        try:   
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
        
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items'][0:10]]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
            
        except: 
            # When error occurs - most likely because comments are disabled on a video
            print('Could not get comments for video ' + video_id)
        
    return pd.DataFrame(all_comments)

# %% [markdown]
# ### 2.6 Channel Statistics

# %%
channel_data = get_channel_stats(youtube, channel_ids)

#printing channel data
channel_data
# Out:
#   channelName subscribers  views totalVideos                playlistId
# 0       Ayusy         442  28454          99  UUKp9UfULbI3n6_VdUxV2_jg

# %% [markdown]
# I noticed the count columns in channel_data is currently in string format, so I will convert them into numeric so that we can visualize and do numeric operations on them.

# %%
# Convert count columns to numeric columns
numeric_cols = ['subscribers', 'views', 'totalVideos']
channel_data[numeric_cols] = channel_data[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# ### 2.7 Get Video Statistics

# %%
# Create a dataframe with video statistics and comments from all channels

video_df = pd.DataFrame()
comments_df = pd.DataFrame()

for c in channel_data['channelName'].unique():
    print("Getting video information from channel: " + c)
    playlist_id = channel_data.loc[channel_data['channelName'] == c, 'playlistId'].iloc[0]
    video_ids = get_video_ids(youtube, playlist_id)
    
    # get video data
    video_data = get_video_details(youtube, video_ids)
    
    # get comment data
    comments_data = get_comments_in_videos(youtube, video_ids)

    # Concatenate video and comment data to the respective DataFrames
    video_df = pd.concat([video_df, video_data], ignore_index=True)
    comments_df = pd.concat([comments_df, comments_data], ignore_index=True)
# Out:
# Getting video information from channel: Ayusy

# %%
video_df
# Out:
#        video_id channelTitle  \
# 0   5YIizZRrY2E        Ayusy
# 1   Jihjev1rLdQ        Ayusy
# 2   F5QfEw6M6Ec        Ayusy
# 3   DMApIAjE6N0        Ayusy
# 4   A77yyxehy9g        Ayusy
# ..          ...          ...
# 94  gbVu7f5ea_o        Ayusy
# 95  KWr5CnXDPt0        Ayusy
# 96  2u0uVV9lPeo        Ayusy
# 97  NQEA2lHjiw0        Ayusy
# 98  bUB4fCsydaM        Ayusy
#
#                                                 title  \
# 0                                        COLD | Ayusy
# 1                                       fika. | Ayusy
# 2          Chill Jam #69 [w/ Launchpad X and Ableton]
# 3   Chill Jam #68 [w/ Novation Launchkey Mini MKII...
# 4   Chill Jam #67 [w/ Novation Launchkey Mini MKII...
# ..                                                ...
# 94                    Create what could exist | Ayusy
# 95              CREATE WHAT COULD EXIST | Performance
# 96                       Can any body hear me | Ayusy
# 97                                     Ambedo | Ayusy
# ...

# %%
comments_df
# Out:
#        video_id                                           comments
# 0   5YIizZRrY2E                                            [noice]
# 1   Jihjev1rLdQ  [OMG Aayush! listening to this on loop🔥, Aweso...
# 2   F5QfEw6M6Ec                          [❤️❤️, ✊👏, 加油gambateh, 🤍]
# 3   DMApIAjE6N0                                                 []
# 4   A77yyxehy9g                                                 []
# ..          ...                                                ...
# 94  gbVu7f5ea_o                                                 []
# 95  KWr5CnXDPt0                                   [Coool creation]
# 96  2u0uVV9lPeo                                                 []
# 97  NQEA2lHjiw0       [straight into my playlist...good job bro 😃]
# 98  bUB4fCsydaM  [Nice piece brother… keep on the spirit🤘., Fin...
#
# [99 rows x 2 columns]

# %% [markdown]
# Saving Data Frame into a CSV file for later

# %%
# Write video data to CSV file for future references
video_df.to_csv('video_data.csv')
comments_df.to_csv('comments_data.csv')

# %% [markdown]
# ## 3. Data Pre-Processing & Feature Engineering

# %% [markdown]
# ### 3.1 Checking for Null Values

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.publishedAt.sort_values().value_counts()
# Out:
# publishedAt
# 2017-04-06T03:46:02Z    1
# 2021-06-20T14:51:14Z    1
# 2021-06-12T14:45:13Z    1
# 2021-06-04T05:18:36Z    1
# 2021-05-23T15:15:17Z    1
#                        ..
# 2020-09-04T14:45:11Z    1
# 2020-08-30T14:45:24Z    1
# 2020-08-22T14:45:11Z    1
# 2020-08-15T15:24:58Z    1
# 2022-12-05T01:41:21Z    1
# Name: count, Length: 99, dtype: int64

# %% [markdown]
# Checking if the data type of the columns are correct. Some count columns such as 'view count' and 'comment count' are currently not in correct data type.
# In this step, we convert these count columns into integer.

# %%
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[cols] = video_df[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %% [markdown]
# ### 3.2 Enriching Data
# I want to enrich the data for further analyses, for example:
#
# - create published date column with another column showing the day in the week the video was published, which will be useful for later analysis.
#
# - convert video duration to seconds instead of the current default string format
#
# - calculate number of tags for each video
#
# - calculate comments and likes per 1000 view ratio
#
# - calculate title character length

# %%
# Convert 'publishedAt' to datetime format
video_df['publishedAt'] = pd.to_datetime(video_df['publishedAt'], errors='coerce')

# Now apply strftime to extract the day of the week
video_df['publishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A") if pd.notnull(x) else None)


# Directly apply strftime to extract the day of the week from 'publishedAt'
video_df['publishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# Convert duration to seconds and remove the decimal
video_df['durationSecs'] = video_df['duration'].apply(lambda x: int(isodate.parse_duration(x).total_seconds()))

# Add number of tags
video_df['tagsCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# Comments and likes per 1000 view ratio
video_df['likeRatio'] = video_df['likeCount']/ video_df['viewCount'] * 1000
video_df['commentRatio'] = video_df['commentCount']/ video_df['viewCount'] * 1000

# Title character length
video_df['titleLength'] = video_df['title'].apply(lambda x: len(x))

video_df['publishedAt'] = pd.to_datetime(video_df['publishedAt'])
    
# Convert duration to seconds if it's not already
if 'durationSecs' not in video_df.columns:
        video_df['durationSecs'] = video_df['duration'].apply(lambda x: 
            sum(int(i) * j for i, j in zip(
                x.replace('PT','').replace('H',':').replace('M',':').replace('S','').split(':')[::-1],
                [1, 60, 3600][:len(x.replace('PT','').replace('H',':').replace('M',':').replace('S','').split(':'))]
            ))
        )

# %%
video_df.head()
# Out:
#       video_id channelTitle  \
# 0  5YIizZRrY2E        Ayusy
# 1  Jihjev1rLdQ        Ayusy
# 2  F5QfEw6M6Ec        Ayusy
# 3  DMApIAjE6N0        Ayusy
# 4  A77yyxehy9g        Ayusy
#
#                                                title  \
# 0                                       COLD | Ayusy
# 1                                      fika. | Ayusy
# 2         Chill Jam #69 [w/ Launchpad X and Ableton]
# 3  Chill Jam #68 [w/ Novation Launchkey Mini MKII...
# 4  Chill Jam #67 [w/ Novation Launchkey Mini MKII...
#
#                                          description  \
# 0  🔲 FOLLOW ME ON:\n▪️Spotify: https://open.spoti...
# 1  🔲 FOLLOW ME ON:\n▪️Spotify: https://open.spoti...
# 2  🔲 FOLLOW ME ON:\n▪️Spotify: https://open.spoti...
# 3  🔲 FOLLOW ME ON:\n▪️Spotify: https://open.spoti...
# 4  🔲 FOLLOW ME ON:\n▪️Spotify: https://open.spoti...
#
#                                                 tags  \
# 0  [ayusy, chillhop, chillbeats, chillmusic, lofi...
# ...

# %%
video_df.to_csv('video_data.csv')

# %% [markdown]
# ## 4. Exploratory Analysis

# %% [markdown]
# ### 4.1 Summary Statistics

# %%
# Summary statistics for numerical columns
video_df.describe()
# Out:
#          viewCount   likeCount  favouriteCount  commentCount  durationSecs  \
# count    99.000000   99.000000             0.0     99.000000     99.000000
# mean    287.414141   17.424242             NaN      4.545455    205.121212
# std     487.367188   18.095603             NaN      4.433805    192.037266
# min      30.000000    5.000000             NaN      0.000000     16.000000
# 25%      98.000000   10.000000             NaN      2.000000    142.500000
# 50%     155.000000   13.000000             NaN      4.000000    157.000000
# 75%     286.000000   17.500000             NaN      6.000000    186.000000
# max    4356.000000  157.000000             NaN     26.000000   1646.000000
#
#        tagsCount   likeRatio  commentRatio  titleLength
# count  99.000000   99.000000     99.000000    99.000000
# mean   45.050505   89.564229     24.834976    55.484848
# std    12.312573   46.481417     27.160070    26.443379
# min     0.000000   20.627063      0.000000    12.000000
# ...

# %% [markdown]
# ### 4.2 Analyzing Distribution of Key Metrics
# Let's analyze the distribution of key metrics such as views, likes, and comments to understand the spread and detect any outliers.

# %%
# Distribution of views, likes, and comments
fig, axs = plt.subplots(1, 3, figsize=(18, 6))
sns.histplot(video_df['viewCount'], bins=30, kde=True, ax=axs[0], color='skyblue')
axs[0].set_title('Distribution of Views')
sns.histplot(video_df['likeCount'], bins=30, kde=True, ax=axs[1], color='lightgreen')
axs[1].set_title('Distribution of Likes')
sns.histplot(video_df['commentCount'], bins=30, kde=True, ax=axs[2], color='salmon')
axs[2].set_title('Distribution of Comments')
plt.show()

# %% [markdown]
# The distributions for views, likes, and comments show similar trends, with right-skewed distributions heavily concentrated in the lower ranges. This implies that only a small subset of videos achieves high engagement across all metrics, likely driven by content quality, relevancy, or other influential factors. Most videos are struggling to reach significant engagement levels, which may indicate challenges with content reach or audience appeal in general.

# %% [markdown]
# ### 4.3 Publish Day Analysis
# Let's examine how views and engagement metrics vary by the day of the week the video was published.

# %%
# Average views, likes, and comments by publish day
day_metrics = video_df.groupby('publishDayName').agg({'viewCount': 'mean', 
                                                      'likeCount': 'mean', 
                                                      'commentCount': 'mean'}).sort_index()

# Plotting the metrics
day_metrics.plot(kind='bar', figsize=(12, 6))
plt.title('Average Views, Likes, and Comments by Publish Day')
plt.xlabel('Day of the Week')
plt.ylabel('Average Count')
plt.show()

# %% [markdown]
# Shows average views, likes, and comments by day, revealing trends like whether weekends have higher views than weekdays.
#
# **Optimal Days for Engagement**: Publishing on Saturday seems most effective for maximizing engagement across views, likes, and comments. Sunday is also favorable, but with slightly lower engagement metrics.
#
# **Less Effective Days**: Monday, Tuesday, and Wednesday appear to yield lower average engagement, suggesting these may not be optimal days for publishing content.

# %% [markdown]
# ### 4.4 Video Duration Analysis
# Now we will analyze the relationship between video duration and engagement (views, likes, comments) to see if certain video lengths perform better.

# %%
# Scatter plot for video duration vs views, likes, comments
fig, axs = plt.subplots(1, 3, figsize=(18, 6))
sns.scatterplot(data=video_df, x='durationSecs', y='viewCount', ax=axs[0], color='purple')
axs[0].set_title('Video Duration vs Views')
sns.scatterplot(data=video_df, x='durationSecs', y='likeCount', ax=axs[1], color='blue')
axs[1].set_title('Video Duration vs Likes')
sns.scatterplot(data=video_df, x='durationSecs', y='commentCount', ax=axs[2], color='orange')
axs[2].set_title('Video Duration vs Comments')
plt.show()

# %% [markdown]
# **Optimal Duration**: Videos shorter than 500 seconds (about 8 minutes) tend to attract higher engagement across views, likes, and comments.
#
# **Engagement Drop-off**: Longer videos (especially beyond 500 seconds) generally see lower engagement, implying that viewers may prefer concise content or lose interest in extended videos.

# %% [markdown]
# ### 4.5 Engagement Ratios (Likes and Comments per 1000 Views)
# Next, let’s visualize engagement ratios (likes and comments per 1000 views) to understand engagement patterns across videos.

# %%
# Histograms for like and comment ratios per 1000 views
fig, axs = plt.subplots(1, 2, figsize=(14, 6))
sns.histplot(video_df['likeRatio'], bins=30, kde=True, ax=axs[0], color='cornflowerblue')
axs[0].set_title('Like Ratio (per 1000 views)')
sns.histplot(video_df['commentRatio'], bins=30, kde=True, ax=axs[1], color='coral')
axs[1].set_title('Comment Ratio (per 1000 views)')
plt.show()

# %% [markdown]
# Show how much engagement videos receive relative to their view count, helping identify high-engagement videos regardless of popularity.
#
# **Like Ratio (per 1000 views)**: This histogram shows how frequently videos receive likes relative to their views. A skewed distribution indicates that while a few videos get high engagement, most receive a lower ratio of likes per 1000 views. High-engagement videos can be studied for trends in content type, duration, or other characteristics.
#
# **Comment Ratio (per 1000 views)**: Similarly, this chart shows comment engagement. Videos that receive more comments relative to views may resonate more with the audience. Identifying patterns in these videos can help produce more engaging content.

# %% [markdown]
# ### 4.6 Correlation Analysis
# Correlation analysis helps reveal relationships between metrics, such as whether views correlate with likes and comments.
#
# - Heatmap: Displays correlations between views, likes, comments, duration, and tags count.

# %%
# Correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(video_df[['viewCount', 'likeCount', 'commentCount', 'durationSecs', 'tagsCount']].corr(), 
            annot=True, cmap='coolwarm')
plt.title('Correlation between Video Metrics')
plt.show()

# %% [markdown]
# **Views and Likes (0.94)**: A strong positive correlation suggests that videos with higher views are likely to receive more likes, indicating that content reach and viewer appreciation often go hand-in-hand.
#
# **Views and Comments (0.65)**: A moderate positive correlation indicates that as views increase, comments tend to as well, though not as strongly as likes.
#
# **Duration and Engagement**: The weak negative correlation between duration and other metrics suggests that longer videos do not necessarily yield higher engagement.

# %% [markdown]
# ### 4.7 Tag Count and Title Length Analysis
# Examine if tag count and title length influence views or engagement, providing insights into content optimization.
# Assesses if the number of tags or the length of the title has any impact on view counts.

# %%
# Scatter plots for tag count and title length vs views
fig, axs = plt.subplots(1, 2, figsize=(14, 6))
sns.scatterplot(data=video_df, x='tagsCount', y='viewCount', ax=axs[0], color='green')
axs[0].set_title('Tags Count vs Views')
sns.scatterplot(data=video_df, x='titleLength', y='viewCount', ax=axs[1], color='brown')
axs[1].set_title('Title Length vs Views')
plt.show()

# %% [markdown]
# **Tags Count vs. Views**: This scatter plot shows that while some videos with a higher number of tags perform well, there's no clear trend that more tags lead to higher views. Optimizing relevant tags is essential, but excessive tagging may not yield additional benefits.
#
# **Title Length vs. Views**: The lack of a strong pattern here suggests that title length alone does not significantly influence view count. However, concise and descriptive titles may still help capture attention without necessarily affecting engagement directly.

# %% [markdown]
# ### 4.8 Top Performing Videos
# Identify the top-performing videos by views, and likesto see if any specific features are common among successful videos.

# %%
# Select the top 10 videos by view count
top_videos = video_df.nlargest(10, 'viewCount')

# Set up the plot data
plt.figure(figsize=(12, 8))

# Plot a stacked bar chart with view and like counts
top_videos[['title', 'viewCount', 'likeCount']].set_index('title').plot(
    kind='bar', 
    stacked=True, 
    color=['skyblue', 'salmon'],
    figsize=(14, 8)
)

# Add titles and labels
plt.title('Top 10 Performing Videos: View Count and Like Count')
plt.xlabel('Video Title')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(['View Count', 'Like Count'])

plt.show()

# %% [markdown]
# This stacked bar chart provides a quick comparison of views and likes across the top 10 videos, showing which videos garnered higher engagement relative to their popularity.

# %% [markdown]
# ## Conclusion
#
# **Engagement Distribution**: A small number of videos achieve high engagement, suggesting that most content struggles to reach significant viewership and interaction. This could be due to content quality, relevance, or audience targeting.
#
# **Publishing Day**: Saturday shows the highest engagement across views, likes, and comments, making it an optimal day for posting content. Weekdays, especially Monday to Wednesday, yield lower engagement.
#
# **Video Duration**: Shorter videos (under 8 minutes) tend to perform better, indicating a preference for concise content among viewers.
#
# **Engagement Ratios**: High-engagement videos can be identified by looking at likes and comments per 1000 views, helping to analyze what resonates with the audience.
#
# **Correlations**: Views and likes show a strong positive correlation, while video duration has a weak negative correlation with engagement, suggesting that lengthier videos may not perform as well.
#
# **Tags and Titles**: A higher number of tags does not necessarily lead to more views, and title length has little impact on view count, though clear and descriptive titles may improve visibility.

# %% [markdown]
# ## Way Forward
#
# **1. Optimize Content Quality and Relevance**
#
# - Analyze top-performing videos to understand what content themes, styles, or formats drive higher engagement. Use this information to guide future content creation.
# - Experiment with different content types and monitor engagement to refine what resonates with the target audience.
#
# **2. Publish on Optimal Days**
#
# - Focus on publishing videos on Saturdays and Sundays, with special attention to peak hours, to maximize reach and engagement.
# - Limit postings on less effective days like Monday to Wednesday, or post supplementary content that requires lower engagement.
#
# **3. Focus on Concise Videos**
#
# - Aim for video lengths under 8 minutes to retain viewer attention and boost engagement. If content is lengthy, consider breaking it into a series to maintain audience interest.
#
# **4. Increase Engagement Ratios**
#
# - Promote high-engagement videos across social media to draw more viewers. Identify common factors in these videos to replicate their success.
# - Encourage viewers to like and comment through calls-to-action in videos to boost engagement ratios.
#
# **5. Optimize Tags and Titles**
#
# - Use relevant tags but avoid over-tagging. Prioritize quality over quantity to improve searchability.
# - Keep titles concise and descriptive to capture viewer interest. Experiment with keywords related to trending topics to enhance discoverability.
#
# **6. Experiment with Content-Length and Topics**
#
# - Consider testing different video lengths (within the optimal range) and content themes based on emerging trends and audience feedback.
# - Regularly review audience analytics to identify shifting interests and adapt content strategy accordingly.
